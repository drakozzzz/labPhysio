# %% [markdown]
# Title Lab 5 Report
#
# Purpose To Help familiarize with GitHub and calculate our reaction time both Visual and Auditory to find the averrage and standard deviation.
#
# Procedure For remote lab:
#
# Use this activity to measure visual reaction time: https://humanbenchmark.com/tests/reactiontimeLinks to an external site.
#
# Use this activity to measure auditory reaction time: https://playback.fm/audio-reaction-timeLinks to an external site.
#
# Please construct a bar graph that includes both visual and auditory reaction times with error bars. Here is a tutorial video on how to make error bars in excelLinks to an external site.
#
# If you wish to see the group data for visual reaction times, please enter your data here as well: https://docs.google.com/spreadsheets/d/1MB1ggbDg-0aUO2owdKYVHuUjEoCAA7ctau0ySVu9h7w/edit?usp=sharingLinks to an external site.
#
# Result

# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 225.2
AUD1_MEAN = 203.2
VIS1_STD = 64.5338843
AUD1_STD = 66.42422583

# %%
# build a bar plot
plt.bar(['Person 1 Visual', 'Person 1 Auditory'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')
